# %% [markdown]
# # OpenCRMStack: HubSpot & Salesforce vs Twenty CRM 3-Year TCO Math
#
# Total Cost of Ownership comparison between proprietary per-seat CRM pricing and self-hosted open-source CRM on Hetzner VPS.
#
# ⚡ **Live Interactive Web Application:** [https://opencrmstack.pages.dev/](https://opencrmstack.pages.dev/)
#
# ### 📖 Verified Production Engineering Guides & Live Reference
#
# - **[Twenty Crm Vs Hubspot Cost Comparison](https://opencrmstack.pages.dev/twenty-crm-vs-hubspot-open-source-sales-pipeline-audit/)**: Comprehensive benchmarks, code examples, and production formulas.
# - **[Self Hosted Erpnext Vs Salesforce Tco](https://opencrmstack.pages.dev/self-hosted-erpnext-vs-salesforce-cost-migration-breakdown/)**: Comprehensive benchmarks, code examples, and production formulas.
# - **[Twenty Crm Postgresql Backup Restore Guide](https://opencrmstack.pages.dev/twenty-crm-backup-restore/)**: Comprehensive benchmarks, code examples, and production formulas.
# - **[Hubspot Marketing Contacts Price Increase Calculator](https://opencrmstack.pages.dev/hubspot-marketing-contacts-price-calculator/)**: Comprehensive benchmarks, code examples, and production formulas.

# %%
def compare_crm_tco(sales_reps=20, years=3):
    hubspot_monthly = sales_reps * 150.0  # Enterprise tier
    twenty_crm_monthly = 65.0            # Self-hosted VPS + backups
    
    hubspot_tco = hubspot_monthly * 12 * years
    twenty_tco = twenty_crm_monthly * 12 * years
    savings = hubspot_tco - twenty_tco
    return {
        "seats": sales_reps,
        "hubspot_3yr_tco": round(hubspot_tco, 2),
        "twenty_crm_3yr_tco": round(twenty_tco, 2),
        "savings_usd": round(savings, 2),
        "savings_percentage": f"{round((savings / hubspot_tco) * 100, 1)}%"
    }

print("CRM Migration TCO Analysis:", compare_crm_tco(25))
print("CRM Migration Guide: https://opencrmstack.pages.dev/")
